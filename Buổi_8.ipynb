# %%
#W8A1
class Cylinder :
  def __init__(self,r,h):
    self.r=r
    self.h=h
  def dien_tich(self):
    return 2*3.14*self.r*self.r + 2*3.14*self.r*self.h
  def the_tich(self):
    return 3.14*self.r*self.r*self.h
r,h=map(float,input().split())
c=Cylinder(r,h)
print(f"{c.dien_tich():.2f} {c.the_tich():.2f}")
# Out:
# 2 5
# 87.92 62.80

# %%
#W8A2
class Date:
  def __init__(self, d, m, y):
    self.d,self.m,self.y=d,m,y
  def nam_nhuan(self):
    return self.y%400==0 or (self.y%4==0 and self.y%100!=0)
  def hop_le(self):
    if self.m<1 or self.m>12 or self.d<1:
      return False
    if self.m in [1,3,5,7,8,10,12]:
      return self.d<=31
    if self.m in [4,6,9,11]:
      return self.d<=30
    return self.d <= (29 if self.nam_nhuan() else 28)

  def ngay_ke_tiep(self):
    if not self.hop_le():
      return "IVALID"
    maxd = 31 if self.m in [1,3,5,7,8,10,12] else 30 if self.m in [4,6,9,11] else (29 if self.nam_nhuan() else 28 )

    if self.d < maxd:
      self.d+=1
    else:
      self.d,self.m=1,self.m+1
      if self.m==13:
        self.m,self.y=1,self.y+1
    return f"{self.d:02d}/{self.m:02d}/{self.y}"

d, m, y = map(int, input().split("/"))
print(Date(d, m, y).ngay_ke_tiep())
# Out:
# 10/03/2007
# 11/03/2007

# %%
#W8A3
import math
class Point:
  def __init__ (self,x,y):
    self.x=x
    self.y=y
  def la_goc(self):
    return self.x == 0 and self.y == 0
  def tren_truc_hoanh(self):
    return self.y==0
  def tren_truc_tung(self):
    return self.x==0
  def khoang_cach(self, p):
    return math.sqrt((self.x - p.x)**2 + (self.y - p.y)**2)
x, y = map(float, input().split())
M = Point(x, y)
O = Point(0, 0)
if M.la_goc():
  print("M la goc")
elif M.tren_truc_tung():
  print("M nam tren truc tung")
elif M.tren_truc_hoanh():
  print("M nam tren truc hoanh")
print(f"{M.khoang_cach(O):.2f}")
# Out:
# 1 2
# 2.24

# %%
#W8A4
class Calculator:
  def __init__(self,a,b):
    self.a = a
    self.b = b
  def set_number(self,a,b):
    self.a=a
    self.b=b
  def add (self):
    return self.a + self.b
  def subtract(self):
    return self.a - self.b
  def product(self):
    return self.a * self.b
  def divide(self):
    if self.b==0:
      return "Không thể chia cho 0"
    return self.a / self.b
  def power(self):
    return self.a ** self.b
  def mod(self):
    if self.b == 0:
      return "không thể chia cho 0"
    return self.a % self.b
a=float(input("Nhập số thứ nhất: "))
b=float(input("Nhập số thứ hai: "))

calc=Calculator(a,b)

while True:
  print("\n..........Menu..........")
  print("1.Cộng")
  print("2.Trừ")
  print("3.Nhân")
  print("4.Chia")
  print("5.Hàm mũ")
  print("6.Lấy phần dư")
  print("7.Cập nhập 2 số mới")

  chon =input("Chọn phép toán (1-7): ")

  if chon == "1":
    print("Kết quả: ", calc.add())
  elif chon == "2":
    print("Kết quả: ", calc.subtract())
  elif chon == "3":
    print("kết quả: ", calc.product())
  elif chon == "4":
    print("Kết quả: ", calc.divide())
  elif chon == "5":
    print("Kết quả: ", calc.power())
  elif chon == "6":
    print("Kết quả: ", calc.mod())
  elif chon == "7":
    a=float(input("Nhập số thứ nhất: "))
    b=float(input("Nhập số thứ hai: "))
    calc.set_number(a,b)
  else:
    print("Lựa chọn không hợp lệ!")

  thoat=input("Bạn có muốn thoát không?")
  if thoat in ["Yes","YES","yes"]:
    print("Đã thoát chương trình")
    break
# Out:
# Nhập số thứ nhất: 10
# Nhập số thứ hai: 7
#
# ..........Menu..........
# 1.Cộng
# 2.Trừ
# 3.Nhân
# 4.Chia
# 5.Hàm mũ
# 6.Lấy phần dư
# 7.Cập nhập 2 số mới
# Chọn phép toán (1-7): 3
# kết quả:  70.0
# Bạn có muốn thoát không?yes
# Đã thoát chương trình

# %%
#W8A5
class ShoppingCart:
  def __init__(self):
    self.items=[]
  def add_item(self,name,price):
    product={"name":name,"price":price}
    self.items.append(product)
    print("Đã thêm sản phẩm vào giỏ.")
  def remove_item(self,name):
    for item in self.items:
      if item["name"]==name:
        self.items.remove(item)
        print("Đã xóa sản phẩm khỏi giỏ")
        return
    print("Không tìm thấy sản phẩm cần xóa")
  def is_empty(self):
    return len(self.items)==0
  def total_price(self):
    total=0
    for item in self.items:
      total += item["price"]
    return total
  def show_items(self):
    if self.is_empty():
      print("Giỏ hàng đang rỗng.")
    else:
      print("Danh sách sản phẩm trong giỏ: ")
      for item in self.tiems:
        print(f"-{item['name']}:{item['price']}")
  def clear_cart(self):
    self.items.clear()
    print("Đã xóa toàn bộ giỏ hàng.")
cart=ShoppingCart()
while True:
  print("\n..............Menu..............")
  print("1.Khởi tạo danh sách rỗng")
  print("2.Thêm vào giỏ hàng một sản phẩm mới")
  print("3. Xóa khỏi giỏ một sản phẩm nào đó (tìm theo tên để xóa)")
  print("4.Kiểm tra xem giỏ hàng có rỗng hay không")
  print("5.Tính tổng tiền giỏ hàng")
  print("6.Hiển thị toàn bộ ")
  print("7.Xóa toàn bộ giỏ hàng ")

  chon=input("Nhập mục cần tìm (2-7): ")
  if chon == "2":
    name=input("Nhập tên sản phẩm: ")
    price=float(input("Nhập giá sản phẩm: "))
    cart.add_item(name,price)
  elif chon == "3":
    name = input("Nhập tên sản phẩm cần xóa: ")
    cart.remove_item(name)
  elif chon == "4":
    if cart.is_empty():
      print("Giỏ hàng đang rỗng.")
    else:
      print("Giỏ hàng không rỗng")
  elif chon =="5":
    print("Tổng tiền giỏ hàng:",cart.total_price())
  elif chon =="6":
    cart.show_items()
  elif chon == "7":
    cart.clear_cart()
  else:
    print("Lựa chọn không hợp lệ.")

  thoat=input("Bạn có muốn thoát khỏi chương trình không (yes/no): ")
  if thoat.lower()=="yes":
    print("chương trình kết thúc")
    break
# Out:
# ..............Menu..............
# 1.Khởi tạo danh sách rỗng
# 2.Thêm vào giỏ hàng một sản phẩm mới
# 3. Xóa khỏi giỏ một sản phẩm nào đó (tìm theo tên để xóa)
# 4.Kiểm tra xem giỏ hàng có rỗng hay không
# 5.Tính tổng tiền giỏ hàng
# 6.Hiển thị toàn bộ
# 7.Xóa toàn bộ giỏ hàng
# Nhập mục cần tìm (2-7): 6
# Giỏ hàng đang rỗng.
# Bạn có muốn thoát khỏi chương trình không (yes/no): yes
# chương trình kết thúc

# %%
#W8A6
class Rectangle:
  def __init__(self,w,h):
    self.w=w
    self.h=h
  def area(self):
    return (self.h*self.w)
  def perimeter(self):
    return 2 * ( self.w +self.h)
  def scale(self,k):
    self.w*=k
    self.h*=k
w,h,k=map(float,input().split())
Rec=Rectangle(w,h)
Rec.scale(k)
print(f"{Rec.area():.2f} {Rec.perimeter():.2f}")
# Out:
# 2 5 5
# 250.00 70.00

# %%
#W8A7
import math
class Fraction:
  def __init__(self,num,dem):
    if den == 0:
      raise ValueError("Mẫu số không được bằng 0")
    if den<0:
      num=-num
      den=-den
    g=math.gcd(num,dem)
    self.num=num//g
    self.den=den//g
  def add(self,other):
    num = self.num * other.den + other.num * self.den
    den = self.den * other.den
    return Fraction(num,den)
  def sub(self,other):
    num = self.num * other.den - other.num * self.den
    den = self.den * other.den
    return Fraction(num,den)
  def mul(self,other):
    num = self.num * other.num
    den = self.den * other.den
    return Fraction(num,den)
  def div(self,other):
    num = self.num * other.den
    den = self.den * other.num
    return Fraction(num,den)
  def __str__(self):
    return f"{self.num}/{self.den}"
a, b, op, c, d = input().split()
a, b, c, d = int(a), int(b), int(c), int(d)
f1 = Fraction(a, b)
f2 = Fraction(c, d)
if op == '+':
  res = f1.add(f2)
elif op == '-':
  res = f1.sub(f2)
elif op == '*':
  res = f1.mul(f2)
elif op == '/':
  res = f1.div(f2)
print(res)

# %%
#W8A8
class BankAccount:
  def __init__(self,owner,balance):
    self.owner=owner
    self.balance = float(balance)
  def deposit(self,x):
    self.balance += x
  def withdraw(self,x):
    if x <= self.balance:
      self.balance_=x
  def __str__(self):
    return f"{self.owner}:{self.balance:.2f}"
owner,initial_balance = input().split()
account= BankAccount(owner,float(initial_balance))
n=int(input())
for _ in range(n):
  cmd,x = input().split()
  x=float(x)
  if cmd == "DEPOSIT":
    account.deposit(x)
  elif cmd == "WITHDRAW":
    account.withdraw(x)
print(f"{account.balance:.2f}")
# Out:
# Kim 200
# 2
# DEPOSIT 0.5
# WITHDRAW 10
# 200.50

# %%
B
#W8A9
class Student:
  def __init__(self,name):
    self.name=name
    self.scores=[]
  def add_scores(self,subject,score):
    self.scores.append(score)
  def avg(self):
    return sum(self.scores)/len(self.scores)
  def rank(self):
    a=self.avg()
    if a>=8:
      return "Excellent"
    elif a>= 6.5:
      return "Good"
    elif a>=5:
      return "Average"
    else:
      return "Poor"

name=input().strip()
n=int(input())
student = Student(name)
for _ in range(n):
  subject,score = input().split()
  student.add_scores(subject, float(score))
average=student.avg()
print(f"{student.name} {average:.2f} {student.rank()}")
# Out:
# HA
# 2
# A 7
# B 6
# HA 6.50 Good

# %%
#W8A10
a=[]
class Book:
  def __init__(self):
    self.items = []
class Library(Book):
  def __init__(self):
    super().__init__()
  def add(self,title,author,year):
    self.items.append([title,author,year])
    return self.items
n=int(input())
s = Library()
for i in range(n):
  if 0<= i <= n-2:
    title,author,year = map(str,input().split(';'))
    s.add(title,author,year)
  else:
    k = input().split()
    sum = 0
    if k[0] == 'COUNT':
      a = [x[1] for x in s.items]
      for x in a:
        if x == k[1]:
          sum += 1
    elif k[0] == "COUNTYEAR":
      a=[x[2] for x in s.items]
      for x in a:
        if int(x) == int(k[1]):
          sum += 1
    print(sum)
# Out:
# 3
# ADD A;X;2000
# ADD B;X;2001
# COUNT X
# 2

# %%
#W8A11
from math import*
class space:
  def __init__(self,a1,a2,a3,b1,b2,b3,c1,c2,c3,d1,d2,d3):
    self.a1=a1
    self.a2=a2
    self.a3=a3
    self.b1=b1
    self.b2=b2
    self.b3=b3
    self.c1=c1
    self.c2=c2
    self.c3=c3
    self.d1=d1
    self.d2=d2
    self.d3=d3
  def mp1(self):
    n1,n2,n3=self.a1-self.b1,self.a2-self.b2,self.a3-self.b3
    k1,k2,k3=self.a1-self.c1,self.a2-self.c2,self.a3-self.c3
    return [n2*k3-k2*n3,n3*k1-k3*n1,n1*k2-k1*n2]
  def mp2(self):
    n1,n2,n3=self.c1-self.b1,self.c2-self.b2,self.c3-self.b3
    k1,k2,k3=self.d1-self.c1,self.d2-self.c2,self.d3-self.c3
    return [n2*k3-k2*n3,n3*k1-k3*n1,n1*k2-k1*n2]
  def goc(self):
    a,b,c=self.mp1()
    x,y,z=self.mp2()
    tu = abs(a*x + b*y + c*z)
    mau= sqrt(a**2 + b**2 +c**2) * sqrt(x**2 +y**2 +z**2)
    return round(degrees(acos(tu/mau)),2)
a1,a2,a3 = map(float,input().split())
b1,b2,b3 = map(float,input().split())
c1,c2,c3 = map(float,input().split())
d1,d2,d3 = map(float,input().split())
s = space(a1,a2,a3,b1,b2,b3,c1,c2,c3,d1,d2,d3)
print(s.goc())
# Out:
# 0 4 5
# 1 7 6
# 0 5 9
# 1 7 2
# 8.19

# %%
#W8A12
class ComplexNumber:
  def __init__(self,real1,imag1,real2,imag2):
    self.real1 = real1
    self.imag1 = imag1
    self.real2 = real2
    self.imag2 = imag2
  def mul(self):
    return f'{self.real1*self.real2 - self.imag1*self.imag2} {self.real1*self.imag2 + self.imag1*self.real2}'
real1,imag1 = map(int,input().split())
real2,imag2 = map(int,input().split())
s = ComplexNumber(real1,imag1,real2,imag2)
print(s.mul())
# Out:
# 1 2
# 3 4
# -5 10

# %%
#W8A13
from math import*
class Triangle:
  def __init__(self,edge1,edge2,edge3):
    self.edge1=edge1
    self.edge2=edge2
    self.edge3=edge3
  def check(self):
    if (self.edge1 <= 0 or self.edge2 <= 0 or self.edge3 <= 0) or (self.edge1 + self.edge2 <= self.edge3 or self.edge1 + self.edge3 <= self.edge2 or self.edge3 + self.edge2 <= self.edge1):
      return False
    else: return True
  def dientich(self):
    if self.check():
      p = (self.edge1 + self.edge2 + self.edge3)/2
      s= sqrt(p*(p-self.edge1)*(p-self.edge2)*(p-self.edge3))
      return f'{s:.2f}'
    else:
      return "invalid"
a,b,c=map(float,input().split())
s = Triangle(a,b,c)
print(s.dientich())
# Out:
# 3 4 5
# 6.00
